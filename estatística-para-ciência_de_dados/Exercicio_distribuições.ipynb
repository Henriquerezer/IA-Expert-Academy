# %%
# código para permitir acesso ao meu google drive, assim poderei importar os dados, sem precisar fazer upload
from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd 
caminho = '/content/gdrive/MyDrive/Colab Notebooks/IA expert /Estatística para ciência de dados/exercícios/census.csv'
data = pd.read_csv(caminho)
data.head(3)
# Out:
# Mounted at /content/gdrive
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States   <=50K
# 1             0             0             13   United-States   <=50K
# 2             0             0             40   United-States   <=50K

# %% [markdown]
# # Agora que você aprendeu os principais tipos de distribuições, o objetivo é utilizar a base de dados do censo para identificar as distribuições para cada um dos atributos. Para isso, carregue o arquivo census.csv e gere o histograma para cada atributo

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# final-weight       int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loos       int64
# hour-per-week      int64
# native-country    object
# income            object
# dtype: object

# %% [markdown]
# Visualização dos histogramas

# %%
sns.displot(data['age'], kde = True).set(title='Distribuição Gama');

# %%
sns.displot(data['final-weight'], kde = True).set(title='Distribuição Gama');

# %%
sns.displot(data['education-num'], kde = True).set(title='Distribuição Binomial');

# %%
sns.displot(data['capital-gain'], kde = True).set(title='Distribuição Exponencial');

# %%
sns.displot(data['capital-loos'], kde = True).set(title='Distribuição Exponencial');

# %%
sns.displot(data['hour-per-week'], kde = True).set(title='Distribuição Poison');

# %%
sns.countplot(data['marital-status']).set(title='Distribuição Binomial');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data['sex']).set(title='Distribuição Bernoulli');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data['income']).set(title='Distribuição Bernoulli');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
